# %%
from typing import List, Tuple
import pandas as pd
import datetime
import requests
import os

# %%
def get_assets(spolka_excel: pd.DataFrame) -> pd.DataFrame:
    assets_line = 29

    non_current_assets_start = 31
    non_current_assets_stop = 43

    current_assets_start = 44
    current_assets_stop = 55

    sale_and_discounting = 55

    called_up_capital = 56

    own_shares = 57

    return pd.concat([
        cut_rows(spolka_excel, assets_line),
        cut_rows(spolka_excel, non_current_assets_start, non_current_assets_stop),
        cut_rows(spolka_excel, current_assets_start, current_assets_stop),
        cut_rows(spolka_excel, sale_and_discounting),
        cut_rows(spolka_excel, called_up_capital),
        cut_rows(spolka_excel, own_shares)
    ], ignore_index=True)

# %%
def get_eq_and_liab(spolka_excel: pd.DataFrame) -> pd.DataFrame:
    eq_and_liab_line = 59

    esotp_start = 61
    esotp_stop = 68

    nc_i_line = 68

    ncl_start = 70
    ncl_stop = 80

    cl_start = 81
    cl_stop = 91

    lrtahfsado_line = 91

    return pd.concat([
        cut_rows(spolka_excel, eq_and_liab_line),
        cut_rows(spolka_excel, esotp_start, esotp_stop),
        cut_rows(spolka_excel, nc_i_line),
        cut_rows(spolka_excel, ncl_start, ncl_stop),
        cut_rows(spolka_excel, cl_start, cl_stop),
        cut_rows(spolka_excel, lrtahfsado_line)
    ], ignore_index=True)

# %%
def get_years(spolka_excel: pd.DataFrame) -> pd.DataFrame:
    year_line = 28
    sl = spolka_excel.iloc[year_line:year_line+1, 2:].reset_index(drop=True)
    sl.columns = range(sl.shape[1])
    sl[0] = 'YEAR'

    return sl.applymap(lambda x: int(x[0:4]) if x != 'YEAR' else 'YEAR')

# %%
def cut_rows(stock_df: pd.DataFrame, start_row: int, stop_row=None) -> pd.DataFrame:
    if stop_row is None:
        rows = stock_df.iloc[start_row:start_row+1, 2:].reset_index(drop=True)
    else:
        rows = stock_df.iloc[start_row:stop_row, 2:].reset_index(drop=True)
    rows.columns = range(rows.shape[1])
    return rows.fillna(0)

# %%
def get_last_price_from_bankier(stock_name: str, from_year: int) -> float:
    date_from = datetime.datetime.fromisoformat(f'{str(from_year)}-12-10T00:00:00+00:00').strftime('%s')
    date_to = datetime.datetime.fromisoformat(f'{str(from_year)}-12-31T23:59:59+00:00').strftime('%s')
    response = requests.get(f'https://www.bankier.pl/new-charts/get-data?date_from={date_from}000&date_to={date_to}000&symbol={stock_name}&intraday=false&type=area')
    return response.json()['main'][-1][-1]

# %%
def prepare_full_info_df(spolka_excel, spolka_name, category):
    print(f'category: {category}, stock: {spolka_name}')
    assets = get_assets(spolka_excel)[list(range(1, spolka_excel.shape[1]-2))]
    assets.columns = range(assets.shape[1])
    
    all_assets = list(assets.T[0]) # full assets value
    
    assets_parts = assets.iloc[1:].reset_index(drop=True)
    assets_parts.columns = range(assets_parts.shape[1])
    
    eq_and_liab = get_eq_and_liab(spolka_excel)[list(range(1, spolka_excel.shape[1]-2))]
    eq_and_liab.columns = range(eq_and_liab.shape[1])
    
    all_eq_and_liab = list(eq_and_liab.T[0])
    
    eq_and_liab_parts = eq_and_liab.iloc[1:].reset_index(drop=True)
    eq_and_liab_parts.columns = range(eq_and_liab_parts.shape[1])

    years = list(get_years(spolka_excel).T[1:][0])
    
    issued_shares = list(get_issued_shares(spolka_excel).T[0])

    
    prices = []

    info_as_dict = {
        'stock_category': [],
        'company': [],
        'year': [],
        'assets': [],
        'assets_change_in_year': [],
        'eq_and_liab': [],
        'eq_and_liab_change_in_year': [],
        'stock_value': [],
        'year_value_change': []
    }
    
    for index, year in enumerate(years):
        try:
            prices.append(get_last_price_from_bankier(spolka_name, year))
        except:
            print(f'Error occured in: {spolka_name}, year: {year}')
            prices.append(-1)
            years[index] = -1
            continue

        if len(info_as_dict['assets_change_in_year']) != 0:
            assets_change_in_year = list(pd.DataFrame(assets_parts[index] / assets_parts[index-1] - 1).fillna(0.0).iloc[:,0])
        else:
            assets_change_in_year = [0.0] * assets_parts.shape[0]

        if len(info_as_dict['eq_and_liab_change_in_year']) != 0:
            eq_and_liab_change_in_year = list(pd.DataFrame(eq_and_liab_parts[index] / eq_and_liab_parts[index-1] - 1).fillna(0.0).iloc[:,0])
        else:
            eq_and_liab_change_in_year = [0.0] * eq_and_liab_parts.shape[0]

        info_as_dict['stock_category'].append(category)
        info_as_dict['company'].append(spolka_name)
        info_as_dict['year'].append(years[index])
        info_as_dict['assets'].append(percentage_list(all_assets[index], assets_parts[index]))
        info_as_dict['assets_change_in_year'].append(assets_change_in_year)
        info_as_dict['eq_and_liab'].append(percentage_list(all_eq_and_liab[index], eq_and_liab_parts[index]))
        info_as_dict['eq_and_liab_change_in_year'].append(eq_and_liab_change_in_year)
        info_as_dict['stock_value'].append(round(issued_shares[index] * prices[index], 2))
        info_as_dict['year_value_change'].append((prices[index]/prices[index-1]) - 1.0 if len(info_as_dict['year_value_change']) != 0 else 0.0)
        
    return info_as_dict

# %%
def get_assets_names_with_id(spolka_excel) -> List[Tuple[int, str]]:
    return list(enumerate(list(get_assets(spolka_excel)[0][1:])))

# %%
def get_eq_and_liab_names_with_id(spolka_excel) -> List[Tuple[int, str]]:
    return list(enumerate(list(get_eq_and_liab(spolka_excel)[0][1:])))

# %%
def get_issued_shares(spolka_excel):
    return cut_rows(spolka_excel, 18).iloc[0:1, 1:].reset_index(drop=True) * 1000

# %%
def percentage_list(full_value, list_of_values):
    return list(list_of_values/full_value)

# %%
def stock_prepared_category(category, category_list):
    xlsxs = list(filter(lambda x: not x.startswith('~'), os.listdir(f'./spolki/{category}')))
    xlsxs.sort()

    for xlsx in xlsxs:
        stock_df = pd.read_excel(f'spolki/{category}/{xlsx}', 'YS', header=None).dropna('columns', 'all')
        stock_name = xlsx.split('.')[0] if not xlsx.startswith('OPONEO.PL') else 'OPONEO.PL' # oponeo is exception in names
        category_list.append(pd.DataFrame.from_dict(prepare_full_info_df(stock_df, stock_name, category)))

# %%
def print_wrong_stock_names(list_of_categories):
    for category in list_of_categories:
        names = list(map(lambda x: x.split('.')[0] if not x.startswith('OPONEO.PL') else 'OPONEO.PL', list(filter(lambda x: not x.startswith('~'), os.listdir(f'./spolki/{category}')))))
        names.sort()
        print()
        print(f'Category: {category}')
        for name in names:
            date_from = datetime.datetime.fromisoformat(f'{str(1990)}-12-10T00:00:00+00:00').strftime('%s')
            date_to = datetime.datetime.fromisoformat(f'{str(1990)}-12-31T23:59:59+00:00').strftime('%s')
            response = requests.get(f'https://www.bankier.pl/new-charts/get-data?date_from={date_from}000&date_to={date_to}000&symbol={name}&intraday=false&type=area')

            if response.status_code == 404:
                print(name)

# %%
cat = {category: [] for category in range(2, 9)}

# %%
for category in range(2, 9):
    stock_prepared_category(category, cat[category])
# Out:
# category: 2, stock: BEDZIN
# Error occured in: BEDZIN, year: 1997
# category: 2, stock: ENEA
# Error occured in: ENEA, year: 2002
# Error occured in: ENEA, year: 2003
# Error occured in: ENEA, year: 2004
# Error occured in: ENEA, year: 2005
# Error occured in: ENEA, year: 2007
# category: 2, stock: ENERGA
# Error occured in: ENERGA, year: 2011
# Error occured in: ENERGA, year: 2012
# category: 2, stock: KOGENERA
# Error occured in: KOGENERA, year: 1997
# Error occured in: KOGENERA, year: 1998
# Error occured in: KOGENERA, year: 1999
# category: 2, stock: LOTOS
# Error occured in: LOTOS, year: 2001
# Error occured in: LOTOS, year: 2002
# Error occured in: LOTOS, year: 2003
# Error occured in: LOTOS, year: 2004
# category: 2, stock: MLSYSTEM
# Error occured in: MLSYSTEM, year: 2017
# category: 2, stock: PEP
# Error occured in: PEP, year: 2001
# Error occured in: PEP, year: 2002
# Error occured in: PEP, year: 2003
# Error occured in: PEP, year: 2004
# category: 2, stock: PETROLINV
# Error occured in: PETROLINV, year: 2006
# category: 2, stock: PGE
# Error occured in: PGE, year: 2008
# category: 2, stock: PGNIG
# Error occured in: PGNIG, year: 2001
# Error occured in: PGNIG, year: 2002
# Error occured in: PGNIG, year: 2003
# Error occured in: PGNIG, year: 2004
# category: 2, stock: PKNORLEN
# Error occured in: PKNORLEN, year: 1997
# Error occured in: PKNORLEN, year: 1998
# category: 2, stock: SKOTAN
# Error occured in: SKOTAN, year: 1997
# Error occured in: SKOTAN, year: 1998
# category: 2, stock: TAURONPE
# Error occured in: TAURONPE, year: 2009
# category: 2, stock: TERMOREX
# category: 2, stock: UNIMOT
# Error occured in: UNIMOT, year: 2011
# category: 2, stock: ZEPAK
# Error occured in: ZEPAK, year: 2011
# category: 3, stock: ALCHEMIA
# Error occured in: ALCHEMIA, year: 1997
# category: 3, stock: ALUMETAL
# Error occured in: ALUMETAL, year: 2013
# category: 3, stock: ARCTIC
# Error occured in: ARCTIC, year: 2008
# category: 3, stock: BOGDANKA
# Error occured in: BOGDANKA, year: 2008
# category: 3, stock: BORYSZEW
# category: 3, stock: BSCDRUK
# Error occured in: BSCDRUK, year: 2009
# Error occured in: BSCDRUK, year: 2010
# category: 3, stock: CIECH
# Error occured in: CIECH, year: 2001
# Error occured in: CIECH, year: 2002
# Error occured in: CIECH, year: 2003
# Error occured in: CIECH, year: 2004
# category: 3, stock: COGNOR
# category: 3, stock: DREWEX
# Error occured in: DREWEX, year: 2004
# Error occured in: DREWEX, year: 2005
# Error occured in: DREWEX, year: 2006
# Error occured in: DREWEX, year: 2007
# category: 3, stock: DROP
# Error occured in: DROP, year: 2004
# Error occured in: DROP, year: 2005
# Error occured in: DROP, year: 2006
# category: 3, stock: EKOEXPORT
# Error occured in: EKOEXPORT, year: 2007
# Error occured in: EKOEXPORT, year: 2008
# category: 3, stock: ELEMENTAL
# Error occured in: ELEMENTAL, year: 2011
# category: 3, stock: ERG
# Error occured in: ERG, year: 2001
# Error occured in: ERG, year: 2002
# Error occured in: ERG, year: 2003
# Error occured in: ERG, year: 2004
# category: 3, stock: ERGIS
# Error occured in: ERGIS, year: 2003
# Error occured in: ERGIS, year: 2004
# Error occured in: ERGIS, year: 2005
# category: 3, stock: FERRUM
# category: 3, stock: GRUPAAZOTY
# Error occured in: GRUPAAZOTY, year: 2006
# Error occured in: GRUPAAZOTY, year: 2007
# category: 3, stock: IMPEXMET
# category: 3, stock: IZOBLOK
# Error occured in: IZOBLOK, year: 2009
# Error occured in: IZOBLOK, year: 2010
# category: 3, stock: JSW
# Error occured in: JSW, year: 2010
# category: 3, stock: KETY
# category: 3, stock: KGHM
# category: 3, stock: KOMPAP
# category: 3, stock: KPPD
# Error occured in: KPPD, year: 1997
# Error occured in: KPPD, year: 1998
# Error occured in: KPPD, year: 1999
# Error occured in: KPPD, year: 2000
# Error occured in: KPPD, year: 2001
# Error occured in: KPPD, year: 2002
# Error occured in: KPPD, year: 2003
# Error occured in: KPPD, year: 2004
# Error occured in: KPPD, year: 2005
# Error occured in: KPPD, year: 2006
# category: 3, stock: KREC
# Error occured in: KREC, year: 2005
# Error occured in: KREC, year: 2006
# Error occured in: KREC, year: 2007
# category: 3, stock: MENNICA
# Error occured in: MENNICA, year: 1997
# category: 3, stock: MOBRUK
# Error occured in: MOBRUK, year: 2009
# category: 3, stock: ODLEWNIE
# Error occured in: ODLEWNIE, year: 1997
# category: 3, stock: ORZBIALY
# Error occured in: ORZBIALY, year: 2006
# category: 3, stock: PCCEXOL
# Error occured in: PCCEXOL, year: 2009
# Error occured in: PCCEXOL, year: 2010
# Error occured in: PCCEXOL, year: 2011
# category: 3, stock: PCCROKITA
# Error occured in: PCCROKITA, year: 2011
# Error occured in: PCCROKITA, year: 2012
# Error occured in: PCCROKITA, year: 2013
# category: 3, stock: PFLEIDER
# category: 3, stock: PGO
# Error occured in: PGO, year: 2010
# category: 3, stock: PLASTBOX
# Error occured in: PLASTBOX, year: 2000
# Error occured in: PLASTBOX, year: 2001
# Error occured in: PLASTBOX, year: 2002
# Error occured in: PLASTBOX, year: 2003
# category: 3, stock: POLICE
# Error occured in: POLICE, year: 2002
# Error occured in: POLICE, year: 2003
# Error occured in: POLICE, year: 2004
# category: 3, stock: POLWAX
# Error occured in: POLWAX, year: 2011
# Error occured in: POLWAX, year: 2012
# Error occured in: POLWAX, year: 2013
# category: 3, stock: PULAWY
# Error occured in: PULAWY, year: 1997
# Error occured in: PULAWY, year: 1998
# Error occured in: PULAWY, year: 1999
# Error occured in: PULAWY, year: 2002
# Error occured in: PULAWY, year: 2003
# Error occured in: PULAWY, year: 2004
# category: 3, stock: RADPOL
# Error occured in: RADPOL, year: 2004
# Error occured in: RADPOL, year: 2005
# Error occured in: RADPOL, year: 2006
# category: 3, stock: SCOPAK
# Error occured in: SCOPAK, year: 2008
# Error occured in: SCOPAK, year: 2009
# Error occured in: SCOPAK, year: 2010
# Error occured in: SCOPAK, year: 2017
# category: 3, stock: STALPROD
# category: 3, stock: SUWARY
# Error occured in: SUWARY, year: 1997
# category: 4, stock: AMPLI
# Error occured in: AMPLI, year: 2016
# Error occured in: AMPLI, year: 2017
# Error occured in: AMPLI, year: 2018
# category: 4, stock: APATOR
# category: 4, stock: APLISENS
# Error occured in: APLISENS, year: 2007
# Error occured in: APLISENS, year: 2008
# category: 4, stock: APSENERGY
# Error occured in: APSENERGY, year: 2012
# category: 4, stock: ARTERIA
# Error occured in: ARTERIA, year: 2005
# category: 4, stock: ATREM
# Error occured in: ATREM, year: 2007
# category: 4, stock: AWBUD
# Error occured in: AWBUD, year: 1997
# category: 4, stock: BERLING
# Error occured in: BERLING, year: 2009
# category: 4, stock: BOWIM
# Error occured in: BOWIM, year: 2010
# Error occured in: BOWIM, year: 2011
# category: 4, stock: BUDIMEX
# category: 4, stock: BUDOPOL
# Error occured in: BUDOPOL, year: 1997
# category: 4, stock: BUMECH
# Error occured in: BUMECH, year: 2005
# Error occured in: BUMECH, year: 2006
# Error occured in: BUMECH, year: 2007
# Error occured in: BUMECH, year: 2008
# category: 4, stock: CHEMOS
# Error occured in: CHEMOS, year: 2005
# Error occured in: CHEMOS, year: 2006
# Error occured in: CHEMOS, year: 2007
# category: 4, stock: CNT
# Error occured in: CNT, year: 1997
# category: 4, stock: DECORA
# Error occured in: DECORA, year: 2002
# Error occured in: DECORA, year: 2003
# Error occured in: DECORA, year: 2004
# category: 4, stock: DEKPOL
# Error occured in: DEKPOL, year: 2009
# Error occured in: DEKPOL, year: 2010
# Error occured in: DEKPOL, year: 2011
# Error occured in: DEKPOL, year: 2012
# Error occured in: DEKPOL, year: 2013
# Error occured in: DEKPOL, year: 2014
# category: 4, stock: DGA
# Error occured in: DGA, year: 2000
# Error occured in: DGA, year: 2001
# Error occured in: DGA, year: 2002
# Error occured in: DGA, year: 2003
# category: 4, stock: DROZAPOL
# Error occured in: DROZAPOL, year: 2001
# Error occured in: DROZAPOL, year: 2002
# Error occured in: DROZAPOL, year: 2003
# category: 4, stock: EFEKT
# category: 4, stock: ELBUDOWA
# category: 4, stock: ELEKTROTI
# Error occured in: ELEKTROTI, year: 2003
# Error occured in: ELEKTROTI, year: 2004
# Error occured in: ELEKTROTI, year: 2005
# Error occured in: ELEKTROTI, year: 2006
# category: 4, stock: ENAP
# category: 4, stock: ENERGOINS
# Error occured in: ENERGOINS, year: 2006
# category: 4, stock: ENTER
# Error occured in: ENTER, year: 2014
# category: 4, stock: ERBUD
# Error occured in: ERBUD, year: 2005
# Error occured in: ERBUD, year: 2006
# category: 4, stock: ESSYSTEM
# Error occured in: ESSYSTEM, year: 2005
# Error occured in: ESSYSTEM, year: 2006
# category: 4, stock: FAMUR
# Error occured in: FAMUR, year: 2003
# Error occured in: FAMUR, year: 2004
# Error occured in: FAMUR, year: 2005
# category: 4, stock: FASING
# Error occured in: FASING, year: 1997
# Error occured in: FASING, year: 1998
# Error occured in: FASING, year: 1999
# category: 4, stock: FEERUM
# Error occured in: FEERUM, year: 2009
# Error occured in: FEERUM, year: 2010
# Error occured in: FEERUM, year: 2011
# Error occured in: FEERUM, year: 2012
# category: 4, stock: FERRO
# Error occured in: FERRO, year: 2008
# Error occured in: FERRO, year: 2009
# category: 4, stock: GRODNO
# Error occured in: GRODNO, year: 2009
# Error occured in: GRODNO, year: 2010
# category: 4, stock: HERKULES
# Error occured in: HERKULES, year: 2003
# Error occured in: HERKULES, year: 2004
# Error occured in: HERKULES, year: 2005
# category: 4, stock: HYDROTOR
# Error occured in: HYDROTOR, year: 1997
# category: 4, stock: IALBGR
# Error occured in: IALBGR, year: 2005
# Error occured in: IALBGR, year: 2006
# Error occured in: IALBGR, year: 2007
# Error occured in: IALBGR, year: 2008
# Error occured in: IALBGR, year: 2009
# Error occured in: IALBGR, year: 2017
# Error occured in: IALBGR, year: 2018
# category: 4, stock: IMPEL
# Error occured in: IMPEL, year: 2000
# Error occured in: IMPEL, year: 2001
# Error occured in: IMPEL, year: 2002
# category: 4, stock: INSTALKRK
# Error occured in: INSTALKRK, year: 1997
# Error occured in: INSTALKRK, year: 1998
# category: 4, stock: INTERBUD
# Error occured in: INTERBUD, year: 2007
# Error occured in: INTERBUD, year: 2008
# Error occured in: INTERBUD, year: 2009
# category: 4, stock: INTROL
# Error occured in: INTROL, year: 2006
# category: 4, stock: IZOLACJA
# Error occured in: IZOLACJA, year: 1997
# Error occured in: IZOLACJA, year: 1998
# Error occured in: IZOLACJA, year: 1999
# Error occured in: IZOLACJA, year: 2000
# Error occured in: IZOLACJA, year: 2001
# Error occured in: IZOLACJA, year: 2002
# Error occured in: IZOLACJA, year: 2003
# Error occured in: IZOLACJA, year: 2004
# Error occured in: IZOLACJA, year: 2005
# Error occured in: IZOLACJA, year: 2006
# category: 4, stock: IZOSTAL
# Error occured in: IZOSTAL, year: 2005
# Error occured in: IZOSTAL, year: 2006
# Error occured in: IZOSTAL, year: 2007
# Error occured in: IZOSTAL, year: 2008
# Error occured in: IZOSTAL, year: 2009
# Error occured in: IZOSTAL, year: 2010
# category: 4, stock: JWWINVEST
# Error occured in: JWWINVEST, year: 2012
# Error occured in: JWWINVEST, year: 2013
# category: 4, stock: KBDOM
# Error occured in: KBDOM, year: 1998
# Error occured in: KBDOM, year: 1999
# Error occured in: KBDOM, year: 2000
# category: 4, stock: KGL
# Error occured in: KGL, year: 2014
# category: 4, stock: KONSSTALI
# Error occured in: KONSSTALI, year: 2004
# Error occured in: KONSSTALI, year: 2005
# Error occured in: KONSSTALI, year: 2006
# category: 4, stock: KRAKCHEM
# Error occured in: KRAKCHEM, year: 2004
# Error occured in: KRAKCHEM, year: 2005
# Error occured in: KRAKCHEM, year: 2006
# category: 4, stock: LABOPRINT
# Error occured in: LABOPRINT, year: 2011
# Error occured in: LABOPRINT, year: 2012
# Error occured in: LABOPRINT, year: 2013
# category: 4, stock: LENA
# Error occured in: LENA, year: 2002
# Error occured in: LENA, year: 2003
# Error occured in: LENA, year: 2004
# category: 4, stock: LENTEX
# category: 4, stock: LIBET
# Error occured in: LIBET, year: 2008
# Error occured in: LIBET, year: 2009
# Error occured in: LIBET, year: 2010
# category: 4, stock: MANGATA
# Error occured in: MANGATA, year: 2001
# Error occured in: MANGATA, year: 2002
# Error occured in: MANGATA, year: 2003
# Error occured in: MANGATA, year: 2004
# category: 4, stock: MDIENERGIA
# category: 4, stock: MEGARON
# Error occured in: MEGARON, year: 2007
# Error occured in: MEGARON, year: 2008
# Error occured in: MEGARON, year: 2009
# Error occured in: MEGARON, year: 2010
# category: 4, stock: MERCOR
# Error occured in: MERCOR, year: 2006
# category: 4, stock: MFO
# Error occured in: MFO, year: 2010
# Error occured in: MFO, year: 2011
# Error occured in: MFO, year: 2012
# Error occured in: MFO, year: 2013
# category: 4, stock: MIRBUD
# Error occured in: MIRBUD, year: 2005
# Error occured in: MIRBUD, year: 2006
# Error occured in: MIRBUD, year: 2007
# category: 4, stock: MOJ
# Error occured in: MOJ, year: 2003
# Error occured in: MOJ, year: 2004
# Error occured in: MOJ, year: 2005
# Error occured in: MOJ, year: 2006
# category: 4, stock: MOSTALPLC
# Error occured in: MOSTALPLC, year: 1997
# category: 4, stock: MOSTALWAR
# category: 4, stock: MOSTALZAB
# category: 4, stock: NEWAG
# Error occured in: NEWAG, year: 2012
# category: 4, stock: NOVITA
# category: 4, stock: NOWAGALA
# Error occured in: NOWAGALA, year: 2001
# Error occured in: NOWAGALA, year: 2002
# Error occured in: NOWAGALA, year: 2003
# category: 4, stock: OTLOG
# Error occured in: OTLOG, year: 2010
# Error occured in: OTLOG, year: 2011
# Error occured in: OTLOG, year: 2012
# category: 4, stock: PANOVA
# Error occured in: PANOVA, year: 2004
# Error occured in: PANOVA, year: 2005
# Error occured in: PANOVA, year: 2006
# category: 4, stock: PATENTUS
# Error occured in: PATENTUS, year: 2006
# Error occured in: PATENTUS, year: 2007
# Error occured in: PATENTUS, year: 2008
# category: 4, stock: PBG
# Error occured in: PBG, year: 2001
# Error occured in: PBG, year: 2002
# Error occured in: PBG, year: 2003
# category: 4, stock: PEKABEX
# Error occured in: PEKABEX, year: 1997
# Error occured in: PEKABEX, year: 1998
# Error occured in: PEKABEX, year: 2014
# category: 4, stock: PKPCARGO
# Error occured in: PKPCARGO, year: 2012
# category: 4, stock: POLIMEXMS
# category: 4, stock: POZBUD
# Error occured in: POZBUD, year: 2004
# Error occured in: POZBUD, year: 2005
# Error occured in: POZBUD, year: 2006
# Error occured in: POZBUD, year: 2007
# category: 4, stock: PRIMETECH
# Error occured in: PRIMETECH, year: 1997
# category: 4, stock: PROCHEM
# category: 4, stock: PROJPRZEM
# Error occured in: PROJPRZEM, year: 1997
# Error occured in: PROJPRZEM, year: 1998
# category: 4, stock: RAFAKO
# category: 4, stock: RAFAMET
# Error occured in: RAFAMET, year: 1997
# Error occured in: RAFAMET, year: 1998
# Error occured in: RAFAMET, year: 1999
# Error occured in: RAFAMET, year: 2000
# Error occured in: RAFAMET, year: 2001
# Error occured in: RAFAMET, year: 2002
# Error occured in: RAFAMET, year: 2003
# Error occured in: RAFAMET, year: 2004
# Error occured in: RAFAMET, year: 2005
# Error occured in: RAFAMET, year: 2006
# category: 4, stock: RAWLPLUG
# Error occured in: RAWLPLUG, year: 2001
# Error occured in: RAWLPLUG, year: 2002
# Error occured in: RAWLPLUG, year: 2003
# category: 4, stock: REDWOOD
# Error occured in: REDWOOD, year: 2006
# category: 4, stock: RELPOL
# category: 4, stock: REMAK
# category: 4, stock: ROPCZYCE
# category: 4, stock: SECOGROUP
# Error occured in: SECOGROUP, year: 2006
# category: 4, stock: SELENAFM
# Error occured in: SELENAFM, year: 2006
# Error occured in: SELENAFM, year: 2007
# category: 4, stock: SESCOM
# Error occured in: SESCOM, year: 2011
# Error occured in: SESCOM, year: 2012
# Error occured in: SESCOM, year: 2013
# category: 4, stock: SNIEZKA
# Error occured in: SNIEZKA, year: 2000
# Error occured in: SNIEZKA, year: 2001
# Error occured in: SNIEZKA, year: 2002
# Error occured in: SNIEZKA, year: 2003
# category: 4, stock: SONEL
# Error occured in: SONEL, year: 2004
# Error occured in: SONEL, year: 2005
# Error occured in: SONEL, year: 2006
# Error occured in: SONEL, year: 2007
# category: 4, stock: STALEXP
# category: 4, stock: STALPROFI
# Error occured in: STALPROFI, year: 1997
# Error occured in: STALPROFI, year: 1998
# Error occured in: STALPROFI, year: 1999
# category: 4, stock: STAPORKOW
# Error occured in: STAPORKOW, year: 2004
# Error occured in: STAPORKOW, year: 2005
# Error occured in: STAPORKOW, year: 2006
# category: 4, stock: SUNEX
# Error occured in: SUNEX, year: 2009
# Error occured in: SUNEX, year: 2010
# category: 4, stock: TESGAS
# Error occured in: TESGAS, year: 2007
# Error occured in: TESGAS, year: 2008
# category: 4, stock: TIM
# Error occured in: TIM, year: 1997
# category: 4, stock: TORPOL
# Error occured in: TORPOL, year: 2013
# category: 4, stock: TRAKCJA
# Error occured in: TRAKCJA, year: 2006
# Error occured in: TRAKCJA, year: 2007
# category: 4, stock: TRANSPOL
# Error occured in: TRANSPOL, year: 2006
# Error occured in: TRANSPOL, year: 2007
# category: 4, stock: ULMA
# category: 4, stock: UNIBEP
# Error occured in: UNIBEP, year: 2006
# Error occured in: UNIBEP, year: 2007
# category: 4, stock: URSUS
# Error occured in: URSUS, year: 2006
# category: 4, stock: VIGOSYS
# Error occured in: VIGOSYS, year: 2012
# Error occured in: VIGOSYS, year: 2013
# category: 4, stock: VISTAL
# Error occured in: VISTAL, year: 2012
# Error occured in: VISTAL, year: 2013
# category: 4, stock: WADEX
# Error occured in: WADEX, year: 2006
# Error occured in: WADEX, year: 2007
# category: 4, stock: WIELTON
# Error occured in: WIELTON, year: 2004
# Error occured in: WIELTON, year: 2005
# Error occured in: WIELTON, year: 2006
# category: 4, stock: WORKSERV
# Error occured in: WORKSERV, year: 2010
# Error occured in: WORKSERV, year: 2011
# category: 4, stock: ZAMET
# Error occured in: ZAMET, year: 2010
# category: 4, stock: ZASTAL
# Error occured in: ZASTAL, year: 1997
# Error occured in: ZASTAL, year: 1998
# Error occured in: ZASTAL, year: 1999
# Error occured in: ZASTAL, year: 2000
# Error occured in: ZASTAL, year: 2001
# Error occured in: ZASTAL, year: 2002
# Error occured in: ZASTAL, year: 2003
# Error occured in: ZASTAL, year: 2004
# Error occured in: ZASTAL, year: 2005
# Error occured in: ZASTAL, year: 2006
# category: 4, stock: ZPUE
# Error occured in: ZPUE, year: 1997
# Error occured in: ZPUE, year: 1998
# Error occured in: ZPUE, year: 1999
# category: 4, stock: ZREMB
# Error occured in: ZREMB, year: 2004
# Error occured in: ZREMB, year: 2005
# Error occured in: ZREMB, year: 2006
# Error occured in: ZREMB, year: 2007
# Error occured in: ZREMB, year: 2018
# category: 4, stock: ZUE
# Error occured in: ZUE, year: 2007
# Error occured in: ZUE, year: 2008
# Error occured in: ZUE, year: 2009
# category: 5, stock: ACAUTOGAZ
# Error occured in: ACAUTOGAZ, year: 2008
# Error occured in: ACAUTOGAZ, year: 2009
# Error occured in: ACAUTOGAZ, year: 2010
# category: 5, stock: AMBRA
# Error occured in: AMBRA, year: 2002
# Error occured in: AMBRA, year: 2003
# Error occured in: AMBRA, year: 2004
# category: 5, stock: AMICA
# category: 5, stock: ATLANTAPL
# Error occured in: ATLANTAPL, year: 2001
# Error occured in: ATLANTAPL, year: 2002
# Error occured in: ATLANTAPL, year: 2003
# Error occured in: ATLANTAPL, year: 2004
# category: 5, stock: AUTOPARTN
# Error occured in: AUTOPARTN, year: 2015
# category: 5, stock: BAHOLDING
# Error occured in: BAHOLDING, year: 2006
# Error occured in: BAHOLDING, year: 2007
# category: 5, stock: CCC
# Error occured in: CCC, year: 2001
# Error occured in: CCC, year: 2002
# Error occured in: CCC, year: 2003
# category: 5, stock: CDRL
# Error occured in: CDRL, year: 2009
# Error occured in: CDRL, year: 2010
# Error occured in: CDRL, year: 2011
# Error occured in: CDRL, year: 2012
# Error occured in: CDRL, year: 2013
# category: 5, stock: DEBICA
# category: 5, stock: ESOTIQ
# category: 5, stock: FORTE
# category: 5, stock: GLCOSMED
# Error occured in: GLCOSMED, year: 2009
# Error occured in: GLCOSMED, year: 2010
# Error occured in: GLCOSMED, year: 2011
# Error occured in: GLCOSMED, year: 2012
# category: 5, stock: GOBARTO
# Error occured in: GOBARTO, year: 2000
# Error occured in: GOBARTO, year: 2001
# Error occured in: GOBARTO, year: 2002
# category: 5, stock: GROCLIN
# Error occured in: GROCLIN, year: 1997
# category: 5, stock: HARPER
# Error occured in: HARPER, year: 2009
# category: 5, stock: HELIO
# Error occured in: HELIO, year: 2005
# category: 5, stock: INDYKPOL
# category: 5, stock: INTERCARS
# Error occured in: INTERCARS, year: 2001
# Error occured in: INTERCARS, year: 2002
# Error occured in: INTERCARS, year: 2003
# category: 5, stock: INTERSPPL
# Error occured in: INTERSPPL, year: 2002
# Error occured in: INTERSPPL, year: 2003
# Error occured in: INTERSPPL, year: 2004
# Error occured in: INTERSPPL, year: 2005
# category: 5, stock: ITMTRADE
# Error occured in: ITMTRADE, year: 2009
# Error occured in: ITMTRADE, year: 2010
# category: 5, stock: KANIA
# Error occured in: KANIA, year: 1997
# Error occured in: KANIA, year: 1998
# Error occured in: KANIA, year: 1999
# Error occured in: KANIA, year: 2000
# Error occured in: KANIA, year: 2001
# Error occured in: KANIA, year: 2002
# Error occured in: KANIA, year: 2003
# Error occured in: KANIA, year: 2007
# category: 5, stock: KRUSZWICA
# category: 5, stock: KRVITAMIN
# Error occured in: KRVITAMIN, year: 2014
# category: 5, stock: LPP
# Error occured in: LPP, year: 1997
# Error occured in: LPP, year: 1998
# Error occured in: LPP, year: 1999
# Error occured in: LPP, year: 2000
# category: 5, stock: LUBAWA
# category: 5, stock: MAKARONPL
# Error occured in: MAKARONPL, year: 2003
# Error occured in: MAKARONPL, year: 2004
# Error occured in: MAKARONPL, year: 2005
# Error occured in: MAKARONPL, year: 2006
# category: 5, stock: MAXCOM
# Error occured in: MAXCOM, year: 2016
# category: 5, stock: MIRACULUM
# Error occured in: MIRACULUM, year: 2005
# Error occured in: MIRACULUM, year: 2006
# category: 5, stock: MONNARI
# Error occured in: MONNARI, year: 2003
# Error occured in: MONNARI, year: 2004
# Error occured in: MONNARI, year: 2005
# category: 5, stock: OTMUCHOW
# Error occured in: OTMUCHOW, year: 2007
# Error occured in: OTMUCHOW, year: 2008
# Error occured in: OTMUCHOW, year: 2009
# category: 5, stock: PAMAPOL
# Error occured in: PAMAPOL, year: 2002
# Error occured in: PAMAPOL, year: 2003
# Error occured in: PAMAPOL, year: 2004
# Error occured in: PAMAPOL, year: 2005
# category: 5, stock: PEPEES
# category: 5, stock: PRIMAMODA
# Error occured in: PRIMAMODA, year: 2004
# Error occured in: PRIMAMODA, year: 2005
# Error occured in: PRIMAMODA, year: 2006
# category: 5, stock: PROCHNIK
# category: 5, stock: PROTEKTOR
# Error occured in: PROTEKTOR, year: 1997
# category: 5, stock: REDAN
# Error occured in: REDAN, year: 2000
# Error occured in: REDAN, year: 2001
# Error occured in: REDAN, year: 2002
# category: 5, stock: SANOK
# category: 5, stock: SANWIL
# Error occured in: SANWIL, year: 1997
# category: 5, stock: SEKO
# Error occured in: SEKO, year: 2003
# Error occured in: SEKO, year: 2004
# Error occured in: SEKO, year: 2005
# Error occured in: SEKO, year: 2006
# category: 5, stock: SOLAR
# Error occured in: SOLAR, year: 2010
# Error occured in: SOLAR, year: 2011
# category: 5, stock: STELMET
# category: 5, stock: TARCZYNSKI
# Error occured in: TARCZYNSKI, year: 2012
# category: 5, stock: TXM
# Error occured in: TXM, year: 2013
# Error occured in: TXM, year: 2014
# Error occured in: TXM, year: 2015
# category: 5, stock: VRG
# category: 5, stock: WAWEL
# Error occured in: WAWEL, year: 1997
# category: 5, stock: WILBO
# Error occured in: WILBO, year: 1997
# category: 5, stock: WITTCHEN
# Error occured in: WITTCHEN, year: 2014
# category: 5, stock: WOJAS
# Error occured in: WOJAS, year: 2004
# Error occured in: WOJAS, year: 2005
# Error occured in: WOJAS, year: 2006
# Error occured in: WOJAS, year: 2007
# category: 5, stock: ZYWIEC
# category: 6, stock: 11BIT
# category: 6, stock: 4FUNMEDIA
# Error occured in: 4FUNMEDIA, year: 2009
# category: 6, stock: ABCDATA
# Error occured in: ABCDATA, year: 2007
# Error occured in: ABCDATA, year: 2008
# Error occured in: ABCDATA, year: 2009
# category: 6, stock: ABPL
# Error occured in: ABPL, year: 2003
# Error occured in: ABPL, year: 2004
# Error occured in: ABPL, year: 2005
# category: 6, stock: ACTION
# Error occured in: ACTION, year: 2005
# category: 6, stock: AGORA
# Error occured in: AGORA, year: 1997
# Error occured in: AGORA, year: 1998
# category: 6, stock: ARTIFEX
# Error occured in: ARTIFEX, year: 2015
# category: 6, stock: ASMGROUP
# Error occured in: ASMGROUP, year: 2011
# Error occured in: ASMGROUP, year: 2012
# Error occured in: ASMGROUP, year: 2013
# Error occured in: ASMGROUP, year: 2018
# category: 6, stock: ATMGRUPA
# Error occured in: ATMGRUPA, year: 2000
# Error occured in: ATMGRUPA, year: 2001
# Error occured in: ATMGRUPA, year: 2002
# Error occured in: ATMGRUPA, year: 2003
# category: 6, stock: BALTONA
# Error occured in: BALTONA, year: 2008
# Error occured in: BALTONA, year: 2009
# Error occured in: BALTONA, year: 2010
# category: 6, stock: BENEFIT
# Error occured in: BENEFIT, year: 2007
# Error occured in: BENEFIT, year: 2008
# Error occured in: BENEFIT, year: 2009
# Error occured in: BENEFIT, year: 2010
# category: 6, stock: CDPROJEKT
# category: 6, stock: CFI
# Error occured in: CFI, year: 2008
# category: 6, stock: CIGAMES
# Error occured in: CIGAMES, year: 2004
# Error occured in: CIGAMES, year: 2005
# Error occured in: CIGAMES, year: 2006
# category: 6, stock: COMPERIA
# Error occured in: COMPERIA, year: 2009
# Error occured in: COMPERIA, year: 2010
# category: 6, stock: DELKO
# Error occured in: DELKO, year: 2008
# category: 6, stock: DINOPL
# Error occured in: DINOPL, year: 2015
# Error occured in: DINOPL, year: 2016
# category: 6, stock: EUROCASH
# Error occured in: EUROCASH, year: 2001
# Error occured in: EUROCASH, year: 2002
# Error occured in: EUROCASH, year: 2003
# Error occured in: EUROCASH, year: 2004
# category: 6, stock: EUROTEL
# Error occured in: EUROTEL, year: 2003
# Error occured in: EUROTEL, year: 2004
# Error occured in: EUROTEL, year: 2005
# category: 6, stock: HOLLYWOOD
# Error occured in: HOLLYWOOD, year: 2012
# Error occured in: HOLLYWOOD, year: 2013
# category: 6, stock: HUBSTYLE
# Error occured in: HUBSTYLE, year: 2008
# Error occured in: HUBSTYLE, year: 2010
# Error occured in: HUBSTYLE, year: 2011
# category: 6, stock: IMS
# Error occured in: IMS, year: 2010
# Error occured in: IMS, year: 2011
# category: 6, stock: INTERFERI
# Error occured in: INTERFERI, year: 2005
# category: 6, stock: K2INTERNT
# Error occured in: K2INTERNT, year: 2006
# Error occured in: K2INTERNT, year: 2007
# category: 6, stock: KCI
# Error occured in: KCI, year: 1997
# category: 6, stock: KINOPOL
# Error occured in: KINOPOL, year: 2007
# Error occured in: KINOPOL, year: 2008
# Error occured in: KINOPOL, year: 2009
# Error occured in: KINOPOL, year: 2010
# category: 6, stock: KOMPUTRON
# Error occured in: KOMPUTRON, year: 2004
# Error occured in: KOMPUTRON, year: 2005
# Error occured in: KOMPUTRON, year: 2006
# category: 6, stock: LARQ
# Error occured in: LARQ, year: 2004
# Error occured in: LARQ, year: 2005
# Error occured in: LARQ, year: 2006
# Error occured in: LARQ, year: 2007
# category: 6, stock: MEDIACAP
# Error occured in: MEDIACAP, year: 2006
# Error occured in: MEDIACAP, year: 2007
# category: 6, stock: MEXPOLSKA
# Error occured in: MEXPOLSKA, year: 2010
# Error occured in: MEXPOLSKA, year: 2011
# category: 6, stock: MORIZON
# Error occured in: MORIZON, year: 2008
# Error occured in: MORIZON, year: 2009
# Error occured in: MORIZON, year: 2010
# Error occured in: MORIZON, year: 2012
# category: 6, stock: MUZA
# Error occured in: MUZA, year: 1997
# category: 6, stock: NORTCOAST
# Error occured in: NORTCOAST, year: 2002
# Error occured in: NORTCOAST, year: 2003
# Error occured in: NORTCOAST, year: 2004
# Error occured in: NORTCOAST, year: 2005
# category: 6, stock: OEX
# Error occured in: OEX, year: 2002
# Error occured in: OEX, year: 2003
# Error occured in: OEX, year: 2004
# category: 6, stock: OPONEO.PL
# Error occured in: OPONEO.PL, year: 2005
# Error occured in: OPONEO.PL, year: 2006
# category: 6, stock: ORBIS
# category: 6, stock: PLAYWAY
# Error occured in: PLAYWAY, year: 2015
# category: 6, stock: PMPG
# category: 6, stock: RAINBOW
# Error occured in: RAINBOW, year: 2004
# Error occured in: RAINBOW, year: 2005
# Error occured in: RAINBOW, year: 2006
# category: 6, stock: SFINKS
# Error occured in: SFINKS, year: 2000
# Error occured in: SFINKS, year: 2001
# Error occured in: SFINKS, year: 2002
# Error occured in: SFINKS, year: 2003
# Error occured in: SFINKS, year: 2004
# Error occured in: SFINKS, year: 2005
# category: 6, stock: TBULL
# Error occured in: TBULL, year: 2013
# Error occured in: TBULL, year: 2014
# Error occured in: TBULL, year: 2015
# category: 6, stock: TOYA
# Error occured in: TOYA, year: 2010
# category: 6, stock: TSGAMES
# Error occured in: TSGAMES, year: 2017
# category: 6, stock: VIVID
# Error occured in: VIVID, year: 2011
# category: 6, stock: WIRTUALNA
# Error occured in: WIRTUALNA, year: 2011
# Error occured in: WIRTUALNA, year: 2012
# Error occured in: WIRTUALNA, year: 2013
# Error occured in: WIRTUALNA, year: 2014
# category: 7, stock: ADIUVO
# Error occured in: ADIUVO, year: 2014
# category: 7, stock: AIRWAY
# Error occured in: AIRWAY, year: 2012
# category: 7, stock: BIOMEDLUB
# Error occured in: BIOMEDLUB, year: 2009
# Error occured in: BIOMEDLUB, year: 2010
# category: 7, stock: BIOTON
# Error occured in: BIOTON, year: 2001
# Error occured in: BIOTON, year: 2002
# Error occured in: BIOTON, year: 2003
# Error occured in: BIOTON, year: 2004
# category: 7, stock: BRASTER
# Error occured in: BRASTER, year: 2010
# Error occured in: BRASTER, year: 2011
# Error occured in: BRASTER, year: 2012
# category: 7, stock: CLNPHARMA
# Error occured in: CLNPHARMA, year: 2012
# Error occured in: CLNPHARMA, year: 2013
# Error occured in: CLNPHARMA, year: 2014
# Error occured in: CLNPHARMA, year: 2015
# category: 7, stock: CORMAY
# Error occured in: CORMAY, year: 2004
# Error occured in: CORMAY, year: 2005
# Error occured in: CORMAY, year: 2006
# Error occured in: CORMAY, year: 2007
# category: 7, stock: EMCINSMED
# Error occured in: EMCINSMED, year: 2002
# Error occured in: EMCINSMED, year: 2003
# Error occured in: EMCINSMED, year: 2004
# category: 7, stock: ENELMED
# Error occured in: ENELMED, year: 2007
# Error occured in: ENELMED, year: 2008
# Error occured in: ENELMED, year: 2009
# Error occured in: ENELMED, year: 2010
# category: 7, stock: MABION
# Error occured in: MABION, year: 2008
# Error occured in: MABION, year: 2009
# category: 7, stock: MASTERPHA
# Error occured in: MASTERPHA, year: 2012
# Error occured in: MASTERPHA, year: 2013
# Error occured in: MASTERPHA, year: 2014
# Error occured in: MASTERPHA, year: 2015
# category: 7, stock: MEDICALG
# Error occured in: MEDICALG, year: 2009
# Error occured in: MEDICALG, year: 2010
# category: 7, stock: MERCATOR
# Error occured in: MERCATOR, year: 2012
# category: 7, stock: NANOGROUP
# Error occured in: NANOGROUP, year: 2016
# category: 7, stock: NEUCA
# Error occured in: NEUCA, year: 2001
# Error occured in: NEUCA, year: 2002
# Error occured in: NEUCA, year: 2003
# category: 7, stock: OAT
# Error occured in: OAT, year: 2016
# Error occured in: OAT, year: 2017
# category: 7, stock: PBKM
# Error occured in: PBKM, year: 2014
# Error occured in: PBKM, year: 2015
# category: 7, stock: SWISSMED
# Error occured in: SWISSMED, year: 2001
# Error occured in: SWISSMED, year: 2002
# Error occured in: SWISSMED, year: 2003
# category: 7, stock: SYNEKTIK
# Error occured in: SYNEKTIK, year: 2009
# Error occured in: SYNEKTIK, year: 2010
# category: 7, stock: VOXEL
# Error occured in: VOXEL, year: 2009
# Error occured in: VOXEL, year: 2010
# category: 8, stock: AILLERON
# Error occured in: AILLERON, year: 2009
# Error occured in: AILLERON, year: 2010
# category: 8, stock: ARCUS
# Error occured in: ARCUS, year: 2004
# Error occured in: ARCUS, year: 2005
# Error occured in: ARCUS, year: 2006
# category: 8, stock: ASSECOBS
# Error occured in: ASSECOBS, year: 2004
# Error occured in: ASSECOBS, year: 2005
# Error occured in: ASSECOBS, year: 2006
# category: 8, stock: ASSECOPOL
# Error occured in: ASSECOPOL, year: 1997
# category: 8, stock: ASSECOSEE
# Error occured in: ASSECOSEE, year: 2008
# category: 8, stock: ATENDE
# Error occured in: ATENDE, year: 2008
# Error occured in: ATENDE, year: 2009
# Error occured in: ATENDE, year: 2010
# Error occured in: ATENDE, year: 2011
# category: 8, stock: ATM
# Error occured in: ATM, year: 2001
# Error occured in: ATM, year: 2002
# Error occured in: ATM, year: 2003
# category: 8, stock: BETACOM
# Error occured in: BETACOM, year: 2001
# Error occured in: BETACOM, year: 2002
# Error occured in: BETACOM, year: 2003
# category: 8, stock: COMARCH
# category: 8, stock: COMP
# Error occured in: COMP, year: 2001
# Error occured in: COMP, year: 2002
# Error occured in: COMP, year: 2003
# Error occured in: COMP, year: 2004
# category: 8, stock: CUBEITG
# Error occured in: CUBEITG, year: 2007
# Error occured in: CUBEITG, year: 2008
# category: 8, stock: CYFRPLSAT
# Error occured in: CYFRPLSAT, year: 2006
# Error occured in: CYFRPLSAT, year: 2007
# category: 8, stock: DIGITREE
# Error occured in: DIGITREE, year: 2008
# Error occured in: DIGITREE, year: 2009
# Error occured in: DIGITREE, year: 2010
# category: 8, stock: ELZAB
# Error occured in: ELZAB, year: 1997
# category: 8, stock: HYPERION
# Error occured in: HYPERION, year: 2005
# category: 8, stock: IFIRMA
# Error occured in: IFIRMA, year: 2004
# Error occured in: IFIRMA, year: 2005
# Error occured in: IFIRMA, year: 2006
# Error occured in: IFIRMA, year: 2007
# category: 8, stock: LARK
# category: 8, stock: LIVECHAT
# Error occured in: LIVECHAT, year: 2013
# category: 8, stock: LSISOFT
# Error occured in: LSISOFT, year: 2003
# Error occured in: LSISOFT, year: 2004
# Error occured in: LSISOFT, year: 2005
# category: 8, stock: MEDIATEL
# Error occured in: MEDIATEL, year: 2001
# Error occured in: MEDIATEL, year: 2002
# Error occured in: MEDIATEL, year: 2003
# Error occured in: MEDIATEL, year: 2017
# category: 8, stock: NETIA
# Error occured in: NETIA, year: 1997
# Error occured in: NETIA, year: 1998
# Error occured in: NETIA, year: 1999
# category: 8, stock: NTTSYSTEM
# Error occured in: NTTSYSTEM, year: 2003
# Error occured in: NTTSYSTEM, year: 2004
# Error occured in: NTTSYSTEM, year: 2005
# Error occured in: NTTSYSTEM, year: 2006
# category: 8, stock: OPTEAM
# Error occured in: OPTEAM, year: 2009
# category: 8, stock: ORANGEPL
# Error occured in: ORANGEPL, year: 1997
# category: 8, stock: PCGUARD
# Error occured in: PCGUARD, year: 2002
# Error occured in: PCGUARD, year: 2003
# Error occured in: PCGUARD, year: 2004
# Error occured in: PCGUARD, year: 2016
# category: 8, stock: PGSSOFT
# Error occured in: PGSSOFT, year: 2007
# category: 8, stock: PROCAD
# Error occured in: PROCAD, year: 2003
# Error occured in: PROCAD, year: 2004
# Error occured in: PROCAD, year: 2005
# Error occured in: PROCAD, year: 2006
# category: 8, stock: QUANTUM
# Error occured in: QUANTUM, year: 2006
# category: 8, stock: R22
# category: 8, stock: REGNON
# Error occured in: REGNON, year: 2005
# Error occured in: REGNON, year: 2006
# Error occured in: REGNON, year: 2018
# category: 8, stock: SIMPLE
# Error occured in: SIMPLE, year: 1997
# Error occured in: SIMPLE, year: 1998
# Error occured in: SIMPLE, year: 1999
# category: 8, stock: SYGNITY
# category: 8, stock: TALEX
# Error occured in: TALEX, year: 1997
# Error occured in: TALEX, year: 1998
# Error occured in: TALEX, year: 1999
# category: 8, stock: UNIMA
# Error occured in: UNIMA, year: 2003
# Error occured in: UNIMA, year: 2004
# Error occured in: UNIMA, year: 2005
# category: 8, stock: WASKO
# Error occured in: WASKO, year: 2000

# %%
all_categories = pd.concat([
    pd.concat(cat[category], ignore_index=True) for category in range(2, 9)
], ignore_index=True)

# %%
all_categories.to_csv('cleaned_and_prepared_stocks.csv', sep=';')

# %%
orlen_excel = pd.read_excel(f'spolki/2/PKNORLEN.xlsx', 'YS', header=None).dropna('columns', 'all')
assets_names_with_id = get_assets_names_with_id(orlen_excel)
eq_and_liab_names_with_id = get_eq_and_liab_names_with_id(orlen_excel)

eq_and_assets_names_with_ids_df = {
    'type': [],
    'id': [],
    'name': []
}
for asset in assets_names_with_id:
    eq_and_assets_names_with_ids_df['type'].append('asset')
    eq_and_assets_names_with_ids_df['id'].append(asset[0])
    eq_and_assets_names_with_ids_df['name'].append(asset[1])

for eq_and_liab in eq_and_liab_names_with_id:
    eq_and_assets_names_with_ids_df['type'].append('eq_and_liab')
    eq_and_assets_names_with_ids_df['id'].append(eq_and_liab[0])
    eq_and_assets_names_with_ids_df['name'].append(eq_and_liab[1])

pd.DataFrame.from_dict(eq_and_assets_names_with_ids_df).to_csv('assets_and_eq_and_liab_ids.csv', sep=';')
